# %% [markdown]
# <a href="https://colab.research.google.com/github/ankile/MIT6.036-Intro-Machine-Learning/blob/master/lab-10/MIT_6_036_Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MIT 6.036 Spring 2020: Lab10#
#
# This colab notebook runs the companion code for question 3 in MIT 6.036 Lab 10. You can work out your solutions here, then submit your results back on the lab page when ready. If you have not used colab before, ask your partner or a TA for help.
#
# ## <section>**Setup**</section>
#
# First, run the next code block to download and import the code for this lab.

# %%
# !rm -rf code_for_lab10* __MACOSX data .DS_Store
# !wget --quiet https://introml.odl.mit.edu/cat-soop/_static/6.036/labs/lab10/code_for_lab10.zip
# !unzip code_for_lab10.zip
# !mv code_for_lab10/* .

from code_for_lab10 import *

import numpy as np
import math as m
import random

import importlib
# Out:
# Archive:  code_for_lab10.zip
#    creating: code_for_lab10/
#   inflating: code_for_lab10/code_for_lab10.py
#   inflating: code_for_lab10/util.py
#   inflating: code_for_lab10/mdp10.py
#    creating: __MACOSX/
#    creating: __MACOSX/code_for_lab10/
#   inflating: __MACOSX/code_for_lab10/._mdp10.py
#   inflating: code_for_lab10/dist.py
# <style>
#        table#id2, #id2 > tbody > tr > th, #id2 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id2><tr><td id=id2-0-0></td><td id=id2-0-1></td><td id=id2-0-2></td><td id=id2-0-3></td><td id=id2-0-4></td><td id=id2-0-5></td><td id=id2-0-6></td><td id=id2-0-7></td><td id=id2-0-8></td><td id=id2-0-9></td></tr></table>

# %% [markdown]
# ## 3.2 Versus Reality

# %% [markdown]
# Once you run the code below wait patiently until you see a yellow and purple square moving around on a teal background.  Ignore everything else for now.

# %%
try_tabular_batch_q_learning(iters=100)
# Out:
# score (0, 6.0)
# score (10, 8.6)
# score (20, 10.8)
# score (30, 39.2)
# score (40, 29.6)
# score (50, 34.6)
# score (60, 46.4)
# score (70, 42.6)
# score (80, 50.0)
# score (90, 44.6)
# Reward 44
# Reward 27
# Reward 27
# Reward 100
# Reward 25
# Reward 20
# Reward 18
# Reward 76
# Reward 100
# Reward 30
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9de5e39cf73045038f06b8b4c739d55b">
#   <div class="anim-controls">
#     <input id="_anim_slider9de5e39cf73045038f06b8b4c739d55b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9de5e39cf73045038f06b8b4c739d55b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim9de5e39cf73045038f06b8b4c739d55b.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select9de5e39cf73045038f06b8b4c739d55b" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9de5e39cf73045038f06b8b4c739d55b"
#              >
#       <label for="_anim_radio1_9de5e39cf73045038f06b8b4c739d55b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9de5e39cf73045038f06b8b4c739d55b"
#              checked>
#       <label for="_anim_radio2_9de5e39cf73045038f06b8b4c739d55b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9de5e39cf73045038f06b8b4c739d55b"
#              >
#       <label for="_anim_radio3_9de5e39cf73045038f06b8b4c739d55b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9de5e39cf73045038f06b8b4c739d55b";
#     var slider_id = "_anim_slider9de5e39cf73045038f06b8b4c739d55b";
#     var loop_select_id = "_anim_loop_select9de5e39cf73045038f06b8b4c739d55b";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAOJElEQVR4nO3dUYgU9oHH8d9m98yDa/C8ZGm66yGe\
# NK5rmtVdowUrMWCSigTUkDOx1FZludIXL33qU9KXJgTSU5rCMVD6YEDvrSmmkUhNkUiPZdAUQiCk\
# oNzuVlLDnY1utG4mew+9bC/kLlcuE//7Hz+fpx12lB+y7Jf/f4axa3Z2djYAUJlbSg8AgP8PAQOg\
# SgIGQJUEDIAqCRgAVRIwAKokYABUScAAqJKAAVAlAQOgSgIGQJUEDIAqCRgAVRIwAKokYABUScAA\
# qJKAAVAlAQOgSgIGQJUEDIAqCRgAVRIwAKokYABUScAAqJKAAVAlAQOgSgIGQJUEDIAqCRgAVRIw\
# AKokYABUScAAqJKAAVAlAQOgSj2lB9zMunsXpmfJktIzoKPd/dcXS0+Yc35iJu/+e6v0jI4hYAX1\
# LFmSL373QOkZ0NHG//6fS0+Yc

# %% [markdown]
# Click play in the button right below the square. This is a movie of a policy playing the game [No Exit](https://en.wikipedia.org/wiki/No_Exit). It’s kind of like Pong: the purple square is the “ball” and the yellow square is your “paddle”. The actions are to move the paddle up, down, or keep it still.
#
# The state is specified by the positions and velocities of the ball and paddle, with a special added “game over” state.
#
# The transition model is a very approximate physics model of the ball reflecting off walls and the paddle, except if the ball gets past the paddle in the positive x direction, the game is over.
#
# The agent gets a reward of +1 on every step it manages to survive.
#
# When watching the game play out, you’ll sometimes see that the purple square gets near the right-hand border and then suddenly it changes to a state with the purple square in the bottom left and the yellow one in the upper right -- this means that the game terminated and then reset to the initial state.
#
# Now we can go back and look at the other output in the notebook:
#
# * First, we show a table of what happens during learning: after every 20 iterations of batch Q learning, we take the current greedy policy and run it to see what its average score is. This score represents how long the episode ran before the ball ran off the map, or 100 if it lasted for that long.
#
# * Next is a plot of the score as a function of the amount of training.
#
# * Finally, we run the greedy policy with respect to the last Q-value function for 10 games and report the rewards achieved on each game. We also make a movie of these 10 games, which is what we started out looking at.

# %% [markdown]
# **3.2)** Run the code given on the notebook for values of $\epsilon$ in the set ${0,0.5,1}$. Does your observation match your answers from 3.1?
#
#
# Remember that this is a small instance, so sometimes the random noise of the environment might prevent you from seeing any useful information. Run the notebook two or three times if something doesn't line up with your expectation, and then ask for help.

# %%
try_tabular_batch_q_learning(iters=200, eps=0)
# Out:
# score (0, 11.2)
# score (20, 8.7)
# score (40, 14.1)
# score (60, 6.0)
# score (80, 7.2)
# score (100, 11.4)
# score (120, 11.4)
# score (140, 14.1)
# score (160, 6.0)
# score (180, 7.5)
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imga006f3a0a2914763afe3e8949ffc687c">
#   <div class="anim-controls">
#     <input id="_anim_slidera006f3a0a2914763afe3e8949ffc687c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anima006f3a0a2914763afe3e8949ffc687c.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anima006f3a0a2914763afe3e8949ffc687c.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecta006f3a0a2914763afe3e8949ffc687c" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_a006f3a0a2914763afe3e8949ffc687c"
#              >
#       <label for="_anim_radio1_a006f3a0a2914763afe3e8949ffc687c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_a006f3a0a2914763afe3e8949ffc687c"
#              checked>
#       <label for="_anim_radio2_a006f3a0a2914763afe3e8949ffc687c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_a006f3a0a2914763afe3e8949ffc687c"
#              >
#       <label for="_anim_radio3_a006f3a0a2914763afe3e8949ffc687c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga006f3a0a2914763afe3e8949ffc687c";
#     var slider_id = "_anim_slidera006f3a0a2914763afe3e8949ffc687c";
#     var loop_select_id = "_anim_loop_selecta006f3a0a2914763afe3e8949ffc687c";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAODklEQVR4nO3d0Yud9Z3H8c84s/EiE8lmdag7Ewgh\
# 1Ewm1klmYiykwbhEbQhCjLjRSNMmYaD0RuwfoL2pItg11MJyoPRCIbmsEmswNC3BIAyHxIIIYiFh\
# M9lgI0vaZIzNeJy96JquuLjL9ugz35PX62oO8xA+DMO8eX7n4aRvfn5+PgBQzA1NDwCA/w8BA6Ak\
# AQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQB\
# A6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAED\
# oCQBA6AkAQOgJAEDoKSBpgdcz/oHF2dg2bKmZ0BPu/3vLzQ94ZozZ+fywX90mp7RMwSsQQPLluUf\
# f/h40zOgp03/8782PeGaO+872

# %%
try_tabular_batch_q_learning(iters=200, eps=0.5)
# Out:
# score (0, 10.3)
# score (20, 26.5)
# score (40, 42.3)
# score (60, 50.7)
# score (80, 61.4)
# score (100, 68.2)
# score (120, 75.1)
# score (140, 65.4)
# score (160, 73.0)
# score (180, 74.2)
# Reward 18
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7f5ef48c8d7c44a7b11b729293182ab0">
#   <div class="anim-controls">
#     <input id="_anim_slider7f5ef48c8d7c44a7b11b729293182ab0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7f5ef48c8d7c44a7b11b729293182ab0.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim7f5ef48c8d7c44a7b11b729293182ab0.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select7f5ef48c8d7c44a7b11b729293182ab0" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7f5ef48c8d7c44a7b11b729293182ab0"
#              >
#       <label for="_anim_radio1_7f5ef48c8d7c44a7b11b729293182ab0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7f5ef48c8d7c44a7b11b729293182ab0"
#              checked>
#       <label for="_anim_radio2_7f5ef48c8d7c44a7b11b729293182ab0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7f5ef48c8d7c44a7b11b729293182ab0"
#              >
#       <label for="_anim_radio3_7f5ef48c8d7c44a7b11b729293182ab0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7f5ef48c8d7c44a7b11b729293182ab0";
#     var slider_id = "_anim_slider7f5ef48c8d7c44a7b11b729293182ab0";
#     var loop_select_id = "_anim_loop_select7f5ef48c8d7c44a7b11b729293182ab0";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAODklEQVR4nO3d0Yud9Z3H8c84s/EiE8lmdag7Ewgh\
# 1Ewm1klmYiykwbhEbQhCjLjRSNMmYaD0RuwfoL2pItg11MJyoPRCIbmsEmswNC3BIAyHxIIIYiFh\
# M9lgI0vaZIzNeJy96JquuLjL9ugz35PX62oO8xA+DMO8eX7n4aRvfn5+PgBQzA1NDwCA/w8BA6Ak\
# AQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQB\
# A6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAED\
# oCQBA6AkAQOgJAEDoKSBpgdcz/oHF2dg2bKmZ0BPu/3vLzQ94ZozZ+fywX90mp7RMwSsQQPLluUf\
# f/h40zOgp03/8782PeGaO+872

# %%
try_tabular_batch_q_learning(iters=200, eps=1)
# Out:
# score (0, 12.5)
# score (20, 13.2)
# score (40, 38.3)
# score (60, 81.5)
# score (80, 52.3)
# score (100, 56.0)
# score (120, 81.2)
# score (140, 61.4)
# score (160, 87.8)
# score (180, 91.8)
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge4eace35b95641ab8b689097a6858978">
#   <div class="anim-controls">
#     <input id="_anim_slidere4eace35b95641ab8b689097a6858978" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime4eace35b95641ab8b689097a6858978.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anime4eace35b95641ab8b689097a6858978.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anime4eace35b95641ab8b689097a6858978.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecte4eace35b95641ab8b689097a6858978" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e4eace35b95641ab8b689097a6858978"
#              >
#       <label for="_anim_radio1_e4eace35b95641ab8b689097a6858978">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e4eace35b95641ab8b689097a6858978"
#              checked>
#       <label for="_anim_radio2_e4eace35b95641ab8b689097a6858978">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e4eace35b95641ab8b689097a6858978"
#              >
#       <label for="_anim_radio3_e4eace35b95641ab8b689097a6858978">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge4eace35b95641ab8b689097a6858978";
#     var slider_id = "_anim_slidere4eace35b95641ab8b689097a6858978";
#     var loop_select_id = "_anim_loop_selecte4eace35b95641ab8b689097a6858978";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAOJElEQVR4nO3dUYgU9oHH8d9m98yDa/C8ZGm66yGe\
# NK5rmtVdowUrMWCSigTUkDOx1FZludIXL33qU9KXJgTaU5rCMVD6YEDvrSmmWSK1RSI9lkFTCIGQ\
# gnK7W0kNdza60bqZ7D30sr2Qu1y5TPLf//j5PO2wo/yQZb/8/zOMXXNzc3MBgMrcUnoAAPx/CBgA\
# VRIwAKokYABUScAAqJKAAVAlAQOgSgIGQJUEDIAqCRgAVRIwAKokYABUScAAqJKAAVAlAQOgSgIG\
# QJUEDIAqCRgAVRIwAKokYABUScAAqJKAAVAlAQOgSgIGQJUEDIAqCRgAVRIwAKokYABUScAAqJKA\
# AVAlAQOgSgIGQJUEDIAqCRgAVeopPeBm1t27OD3LlpWeAR3t7r++VHrCvAuTs3n731ulZ3QMASuo\
# Z9myfP7bh0rPgI428ff/XHrCv

# %%
try_tabular_batch_q_learning(iters=1000, eps=0.9)
# Out:
# score (0, 7.2)
# score (100, 69.2)
# score (200, 93.1)
# score (300, 100.0)
# score (400, 98.2)
# score (500, 100.0)
# score (600, 100.0)
# score (700, 93.1)
# score (800, 100.0)
# score (900, 100.0)
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf336f4f9a69d49e2bcbae7ed4e79d01d">
#   <div class="anim-controls">
#     <input id="_anim_sliderf336f4f9a69d49e2bcbae7ed4e79d01d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf336f4f9a69d49e2bcbae7ed4e79d01d.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animf336f4f9a69d49e2bcbae7ed4e79d01d.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectf336f4f9a69d49e2bcbae7ed4e79d01d" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f336f4f9a69d49e2bcbae7ed4e79d01d"
#              >
#       <label for="_anim_radio1_f336f4f9a69d49e2bcbae7ed4e79d01d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f336f4f9a69d49e2bcbae7ed4e79d01d"
#              checked>
#       <label for="_anim_radio2_f336f4f9a69d49e2bcbae7ed4e79d01d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f336f4f9a69d49e2bcbae7ed4e79d01d"
#              >
#       <label for="_anim_radio3_f336f4f9a69d49e2bcbae7ed4e79d01d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf336f4f9a69d49e2bcbae7ed4e79d01d";
#     var slider_id = "_anim_sliderf336f4f9a69d49e2bcbae7ed4e79d01d";
#     var loop_select_id = "_anim_loop_selectf336f4f9a69d49e2bcbae7ed4e79d01d";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAODklEQVR4nO3d0Yud9Z3H8c84s/EiE8lmdag7Ewgh\
# 1Ewm1klmYiykwbhEbQhCjLjRSNMmYaD0RuwfoL2pItg11MJyoPRCIbmsEmswNC3BIAyHxIIIYiFh\
# M9lgI0vaZIzNeJy96JquuLjL9ugz35PX62oO8xA+DMO8eX7n4aRvfn5+PgBQzA1NDwCA/w8BA6Ak\
# AQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQB\
# A6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAEDoCQBA6AkAQOgJAED\
# oCQBA6AkAQOgJAEDoKSBpgdcz/oHF2dg2bKmZ0BPu/3vLzQ94ZozZ+fywX90mp7RMwSsQQPLluUf\
# f/h40zOgp03/8782PeGaO+872

# %% [markdown]
# **(Optional)** Once you are done with the check off, play with the number of iterations in the colab until you get all of the methods to find a policy that scores 100 on all 10 of the final trials, and then observe the gameplay of the agents. You might expect the model that learned with $\epsilon = 1$ has a more jittery gameplay than the agent that learned with $\epsilon=0$ or $0.5$. Does that hold?
